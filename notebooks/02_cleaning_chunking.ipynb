# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 02: Cleaning and Chunking\n",
    "\n",
    "## Goal\n",
    "Clean text data and create semantic chunks for vector embedding."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 1: Imports\n",
    "import json\n",
    "import os\n",
    "import re\n",
    "import pandas as pd\n",
    "from pathlib import Path\n",
    "\n",
    "print(\"✅ Libraries imported\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 2: Load raw documents\n",
    "raw_docs = []\n",
    "for file in os.listdir(\"../data/raw\"):\n",
    "    if file.endswith(\".json\") and file != \"summary.json\":\n",
    "        with open(f\"../data/raw/{file}\", \"r\") as f:\n",
    "            raw_docs.append(json.load(f))\n",
    "\n",
    "print(f\"📚 Loaded {len(raw_docs)} documents\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 3: Text cleaning function\n",
    "def clean_text(text):\n",
    "    \"\"\"Clean and normalize text\"\"\"\n",
    "    # Lowercase\n",
    "    text = text.lower()\n",
    "    # Remove extra whitespace\n",
    "    text = re.sub(r'\\s+', ' ', text)\n",
    "    # Remove special characters but keep basic punctuation\n",
    "    text = re.sub(r'[^\\w\\s.,!?-]', '', text)\n",
    "    # Normalize units\n",
    "    text = re.sub(r'(\\d+)\\s*(mmhg|bpm|hr|ms)', r'\\1 \\2', text)\n",
    "    return text.strip()\n",
    "\n",
    "# Test cleaning\n",
    "test_text = \"Blood pressure   should be below 140/90 mmHg!!!\"\n",
    "print(f\"Test cleaning: {clean_text(test_text)}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 4: Chunking function\n",
    "def chunk_text(text, chunk_size=300, overlap=50):\n",
    "    \"\"\"Split text into overlapping chunks\"\"\"\n",
    "    words = text.split()\n",
    "    chunks = []\n",
    "    \n",
    "    if len(words) <= chunk_size:\n",
    "        return [\" \".join(words)]\n",
    "    \n",
    "    for i in range(0, len(words), chunk_size - overlap):\n",
    "        chunk = \" \".join(words[i:i + chunk_size])\n",
    "        chunks.append(chunk)\n",
    "        \n",
    "        # Stop if we've reached the end\n",
    "        if i + chunk_size >= len(words):\n",
    "            break\n",
    "            \n",
    "    return chunks\n",
    "\n",
    "# Test chunking\n",
    "test_long_text = \" \".join([\"word\" + str(i) for i in range(500)])\n",
    "test_chunks = chunk_text(test_long_text, chunk_size=100, overlap=20)\n",
    "print(f\"Test chunking created {len(test_chunks)} chunks\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 5: Process all documents\n",
    "cleaned_chunks = []\n",
    "chunk_id = 0\n",
    "\n",
    "for doc in raw_docs:\n",
    "    cleaned_text = clean_text(doc[\"text\"])\n",
    "    chunks = chunk_text(cleaned_text, chunk_size=300, overlap=50)\n",
    "    \n",
    "    for chunk in chunks:\n",
    "        cleaned_chunks.append({\n",
    "            \"chunk_id\": f\"chunk_{chunk_id}\",\n",
    "            \"source\": doc[\"source\"],\n",
    "            \"title\": doc[\"title\"],\n",
    "            \"text\": chunk,\n",
    "            \"word_count\": len(chunk.split())\n",
    "        })\n",
    "        chunk_id += 1\n",
    "\n",
    "print(f\"✅ Created {len(cleaned_chunks)} chunks from {len(raw_docs)} documents\")\n",
    "print(f\"Average chunk length: {sum([c['word_count'] for c in cleaned_chunks])/len(cleaned_chunks):.0f} words\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 6: Save cleaned chunks\n",
    "with open(\"../data/cleaned/chunks.json\", \"w\") as f:\n",
    "    json.dump(cleaned_chunks, f, indent=2)\n",
    "\n",
    "# Also save as CSV for easy viewing\n",
    "df_chunks = pd.DataFrame(cleaned_chunks)\n",
    "df_chunks.to_csv(\"../data/cleaned/chunks.csv\", index=False)\n",
    "\n",
    "print(\"\\n📊 Chunk Statistics:\")\n",
    "print(df_chunks['source'].value_counts())\n",
    "print(f\"\\n✅ Saved {len(cleaned_chunks)} chunks to data/cleaned/chunks.json and chunks.csv\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Cell 7: Preview chunks\n",
    "print(\"\\n🔍 Sample Chunks:\")\n",
    "for i, chunk in enumerate(cleaned_chunks[:3]):\n",
    "    print(f\"\\nChunk {i+1} ({chunk['source']} - {chunk['title']}):\")\n",
    "    print(f\"{chunk['text'][:150]}...\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.12.7"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# 02: Cleaning and Chunking\n",
#       8     "\n",
#       9     "## Goal\n",
#      10     "Clean text data and create semantic chunks for vector embedding."
#      11    ]
#      12   },
#      13   {
#      14    "cell_type": "code",
# ---> 15    "execution_count": null,
#      16    "metadata": {},
#      17    "outputs": [],
#      18    "source": [
#      19     "# Cell 1: Imports\n",
#      20     "import json\n",
#      21     "import os\n",
#      22     "import re\n",
#      23     "import pandas as pd\n",
#      24     "from pathlib import Path\n",
#      25     "\n",
#      26     "print(\"✅ Libraries imported\")"
#      27    ]
#      28   },
#      29   {
#      30    "cell_type": "code",
#      31    "execution_count": null,
#      32    "metadata": {},
#      33    "outputs": [],
#      34    "source": [
#      35     "# Cell 2: Load raw documents\n",
#      36     "raw_docs = []\n",
#      37     "for file in os.listdir(\"../data/raw\"):\n",
#      38     "    if file.endswith(\".json\") and file != \"summary.json\":\n",
#      39     "        with open(f\"../data/raw/{file}\", \"r\") as f:\n",
#      40     "            raw_docs.append(json.load(f))\n",
#      41     "\n",
#      42     "print(f\"📚 Loaded {len(raw_docs)} documents\")"
#      43    ]
#      44   },
#      45   {
#      46    "cell_type": "code",
#      47    "execution_count": null,
#      48    "metadata": {},
#      49    "outputs": [],
#      50    "source": [
#      51     "# Cell 3: Text cleaning function\n",
#      52     "def clean_text(text):\n",
#      53     "    \"\"\"Clean and normalize text\"\"\"\n",
#      54     "    # Lowercase\n",
#      55     "    text = text.lower()\n",
#      56     "    # Remove extra whitespace\n",
#      57     "    text = re.sub(r'\\s+', ' ', text)\n",
#      58     "    # Remove special characters but keep basic punctuation\n",
#      59     "    text = re.sub(r'[^\\w\\s.,!?-]', '', text)\n",
#      60     "    # Normalize units\n",
#      61     "    text = re.sub(r'(\\d+)\\s*(mmhg|bpm|hr|ms)', r'\\1 \\2', text)\n",
#      62     "    return text.strip()\n",
#      63     "\n",
#      64     "# Test cleaning\n",
#      65     "test_text = \"Blood pressure   should be below 140/90 mmHg!!!\"\n",
#      66     "print(f\"Test cleaning: {clean_text(test_text)}\")"
#      67    ]
#      68   },
#      69   {
#      70    "cell_type": "code",
#      71    "execution_count": null,
#      72    "metadata": {},
#      73    "outputs": [],
#      74    "source": [
#      75     "# Cell 4: Chunking function\n",
#      76     "def chunk_text(text, chunk_size=300, overlap=50):\n",
#      77     "    \"\"\"Split text into overlapping chunks\"\"\"\n",
#      78     "    words = text.split()\n",
#      79     "    chunks = []\n",
#      80     "    \n",
#      81     "    if len(words) <= chunk_size:\n",
#      82     "        return [\" \".join(words)]\n",
#      83     "    \n",
#      84     "    for i in range(0, len(words), chunk_size - overlap):\n",
#      85     "        chunk = \" \".join(words[i:i + chunk_size])\n",
#      86     "        chunks.append(chunk)\n",
#      87     "        \n",
#      88     "        # Stop if we've reached the end\n",
#      89     "        if i + chunk_size >= len(words):\n",
#      90     "            break\n",
#      91     "            \n",
#      92     "    return chunks\n",
#      93     "\n",
#      94     "# Test chunking\n",
#      95     "test_long_text = \" \".join([\"word\" + str(i) for i in range(500)])\n",
#      96     "test_chunks = chunk_text(test_long_text, chunk_size=100, overlap=20)\n",
#      97     "print(f\"Test chunking created {len(test_chunks)} chunks\")"
#      98    ]
#      99   },
#     100   {
#     101    "cell_type": "code",
#     102    "execution_count": null,
#     103    "metadata": {},
#     104    "outputs": [],
#     105    "source": [
#     106     "# Cell 5: Process all documents\n",
#     107     "cleaned_chunks = []\n",
#     108     "chunk_id = 0\n",
#     109     "\n",
#     110     "for doc in raw_docs:\n",
#     111     "    cleaned_text = clean_text(doc[\"text\"])\n",
#     112     "    chunks = chunk_text(cleaned_text, chunk_size=300, overlap=50)\n",
#     113     "    \n",
#     114     "    for chunk in chunks:\n",
#     115     "        cleaned_chunks.append({\n",
#     116     "            \"chunk_id\": f\"chunk_{chunk_id}\",\n",
#     117     "            \"source\": doc[\"source\"],\n",
#     118     "            \"title\": doc[\"title\"],\n",
#     119     "            \"text\": chunk,\n",
#     120     "            \"word_count\": len(chunk.split())\n",
#     121     "        })\n",
#     122     "        chunk_id += 1\n",
#     123     "\n",
#     124     "print(f\"✅ Created {len(cleaned_chunks)} chunks from {len(raw_docs)} documents\")\n",
#     125     "print(f\"Average chunk length: {sum([c['word_count'] for c in cleaned_chunks])/len(cleaned_chunks):.0f} words\")"
#     126    ]
#     127   },
#     128   {
#     129    "cell_type": "code",
#     130    "execution_count": null,
#     131    "metadata": {},
#     132    "outputs": [],
#     133    "source": [
#     134     "# Cell 6: Save cleaned chunks\n",
#     135     "with open(\"../data/cleaned/chunks.json\", \"w\") as f:\n",
#     136     "    json.dump(cleaned_chunks, f, indent=2)\n",
#     137     "\n",
#     138     "# Also save as CSV for easy viewing\n",
#     139     "df_chunks = pd.DataFrame(cleaned_chunks)\n",
#     140     "df_chunks.to_csv(\"../data/cleaned/chunks.csv\", index=False)\n",
#     141     "\n",
#     142     "print(\"\\n📊 Chunk Statistics:\")\n",
#     143     "print(df_chunks['source'].value_counts())\n",
#     144     "print(f\"\\n✅ Saved {len(cleaned_chunks)} chunks to data/cleaned/chunks.json and chunks.csv\")"
#     145    ]
#     146   },
#     147   {
#     148    "cell_type": "code",
#     149    "execution_count": null,
#     150    "metadata": {},
#     151    "outputs": [],
#     152    "source": [
#     153     "# Cell 7: Preview chunks\n",
#     154     "print(\"\\n🔍 Sample Chunks:\")\n",
#     155     "for i, chunk in enumerate(cleaned_chunks[:3]):\n",
#     156     "    print(f\"\\nChunk {i+1} ({chunk['source']} - {chunk['title']}):\")\n",
#     157     "    print(f\"{chunk['text'][:150]}...\")"
#     158    ]
#     159   }
#     160  ],
#     161  "metadata": {
#     162   "kernelspec": {
#     163    "display_name": "Python 3",
#     164    "language": "python",
#     165    "name": "python3"
#     166   },
#     167   "language_info": {
#     168    "name": "python",
#     169    "version": "3.12.7"
#     170   }
#     171  },
#     172  "nbformat": 4,
#     173  "nbformat_minor": 4
#     174 }
#
# NameError: name 'null' is not defined
